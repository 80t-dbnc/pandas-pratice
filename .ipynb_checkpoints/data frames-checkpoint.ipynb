# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["name","age","city","salary"]
df2 = pd.DataFrame(data_list,columns = columns)
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: name, dtype: str

# %%
df2['city']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# 3      London
# Name: city, dtype: str

# %%
df2[['name','city']]
# Out:
#     name      city
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2["fanatsy"] = ["anal","brutal","bbc","blacked"]

# %%
df2
# Out:
#     name  age      city  salary  fanatsy
# 0   John   28  New York   65000     anal
# 1   Anna   34     Paris   70000   brutal
# 2  Peter   29    Berlin   62000      bbc
# 3  Linda   42    London   85000  blacked

# %%
df2["friends"] = ["anshuman","tanmay","swastik","asit"]
df2[" fav pornstar"] = ["eva elfie", "alxy star","lary fox","eliaza ibrara"]
df2
# Out:
#    age      city  salary  fanatsy   friends   fav pornstar
# 0   28  New York   65000     anal  anshuman      eva elfie
# 1   34     Paris   70000   brutal    tanmay      alxy star
# 2   29    Berlin   62000      bbc   swastik       lary fox
# 3   42    London   85000  blacked      asit  eliaza ibrara

# %%
df2.drop("age",axis = 1,inplace = True)

# %%
df2
# Out:
#        city  salary  fanatsy   friends   fav pornstar
# 0  New York   65000     anal  anshuman      eva elfie
# 1     Paris   70000   brutal    tanmay      alxy star
# 2    Berlin   62000      bbc   swastik       lary fox
# 3    London   85000  blacked      asit  eliaza ibrara

# %%
df2.drop(0,axis = 0)
# Out:
#      city  salary  fanatsy  friends   fav pornstar
# 1   Paris   70000   brutal   tanmay      alxy star
# 2  Berlin   62000      bbc  swastik       lary fox
# 3  London   85000  blacked     asit  eliaza ibrara

# %%
df2
# Out:
#        city  salary  fanatsy   friends   fav pornstar
# 0  New York   65000     anal  anshuman      eva elfie
# 1     Paris   70000   brutal    tanmay      alxy star
# 2    Berlin   62000      bbc   swastik       lary fox
# 3    London   85000  blacked      asit  eliaza ibrara

# %%
df2.drop(3,axis =0,inplace = True)

# %%
df2
# Out:
#        city  salary fanatsy   friends  fav pornstar
# 0  New York   65000    anal  anshuman     eva elfie
# 1     Paris   70000  brutal    tanmay     alxy star
# 2    Berlin   62000     bbc   swastik      lary fox

# %%
df2.loc[[0,2]]
# Out:
#        city  salary fanatsy   friends  fav pornstar
# 0  New York   65000    anal  anshuman     eva elfie
# 2    Berlin   62000     bbc   swastik      lary fox

# %%
df2.loc[0]
# Out:
# city              New York
# salary               65000
# fanatsy               anal
# friends           anshuman
#  fav pornstar    eva elfie
# Name: 0, dtype: object

# %%
df2.iloc[[0,2]]
# Out:
#        city  salary fanatsy   friends  fav pornstar
# 0  New York   65000    anal  anshuman     eva elfie
# 2    Berlin   62000     bbc   swastik      lary fox

# %%
df2
# Out:
#        city  salary fanatsy   friends  fav pornstar
# 0  New York   65000    anal  anshuman     eva elfie
# 1     Paris   70000  brutal    tanmay     alxy star
# 2    Berlin   62000     bbc   swastik      lary fox

# %%
df2.loc[[1,2]] [["friends"," fav pornstar"]]
# Out:
#    friends  fav pornstar
# 1   tanmay     alxy star
# 2  swastik      lary fox

# %%
df2.loc[[1,2]] [["city","salary"]]
# Out:
#      city  salary
# 1   Paris   70000
# 2  Berlin   62000

# %%
# conditional slection

# %%
df2["size"] = [15,12,20]

# %%
df2
# Out:
#        city  salary fanatsy   friends  fav pornstar  size
# 0  New York   65000    anal  anshuman     eva elfie    15
# 1     Paris   70000  brutal    tanmay     alxy star    12
# 2    Berlin   62000     bbc   swastik      lary fox    20

# %%
df2[df2["size"] > 13]
# Out:
#        city  salary fanatsy   friends  fav pornstar  size
# 0  New York   65000    anal  anshuman     eva elfie    15
# 2    Berlin   62000     bbc   swastik      lary fox    20

# %%
df2[(df2["size"] > 13) & (df2["fanatsy"] == 'anal')]
# Out:
#        city  salary fanatsy   friends  fav pornstar  size
# 0  New York   65000    anal  anshuman     eva elfie    15
