# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    308     57   John  January      Q1
# 1  2023-01-02       B   West    900     89   Mary  January      Q1
# 2  2023-01-03       C  North    142     78    Bob  January      Q1
# 3  2023-01-04       D  South    842     46  Alice  January      Q1
# 4  2023-01-05       A   East    734     58   John  January      Q1
# 5  2023-01-06       B   West    452     95   Mary  January      Q1
# 6  2023-01-07       C  North    987     62    Bob  January      Q1
# 7  2023-01-08       D  South    277     17  Alice  January      Q1
# 8  2023-01-09       A   East    178     26   John  January      Q1
# 9  2023-01-10       B   West    928     64   Mary  January      Q1
# 10 2023-01-11       C  North    251     67    Bob  January      Q1
# 11 2023-01-12       D  South    664     56  Alice  January      Q1
# 12 2023-01-13       A   East    735     11   John  January      Q1
# 13 2023-01-14       B   West    172     86   Mary  January      Q1
# 14 2023-01-15       C  North    166     75    Bob  January      Q1
# 15 2023-01-16       D  South    624     80  Alice  January      Q1
# 16 2023-01-17       A   East    743     76   John  January      Q1
# 17 2023-01-18       B   West    476     36   Mary  January      Q1
# 18 2023-01-19       C  North    739     70    Bob  January      Q1
# 19 2023-01-20       D  South    394     46  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index = "Region",columns = "Product",aggfunc = "median")
# Out:
# Product      A      B      C      D
# Region
# East     734.0    NaN    NaN    NaN
# North      NaN    NaN  251.0    NaN
# South      NaN    NaN    NaN  624.0
# West       NaN  476.0    NaN    NaN

# %%
#here in plcae of value it must the terms which has anumeric values bcz agar aisa nhi hoga to aggregation function work nhi krega
#alphabets pe
#

# %%
pivot2 = pd.pivot_table(df,values = ["Sales","Units"],index = "Region",columns = "Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     539.6    NaN    NaN    NaN  45.6   NaN   NaN   NaN
# North      NaN    NaN  457.0    NaN   NaN   NaN  70.4   NaN
# South      NaN    NaN    NaN  560.2   NaN   NaN   NaN  49.0
# West       NaN  585.6    NaN    NaN   NaN  74.0   NaN   NaN

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
